# %% [markdown]
# # Ejemplos clase

# %% [markdown]
# ## Distribución Gaussiana

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import scipy.stats as st
# %matplotlib inline

# %%
p1 = st.norm() 

mu = 70 
sigma = 2
x1 = 74
x2 = 66

# %%
x = np.linspace(64.0, 76.0) # range of x in spec

# %%
Ho=  norm.pdf(x, 70, np.sqrt(2))

# %%
Ho
# Out:
# array([3.48132630e-05, 7.15000793e-05, 1.42509858e-04, 2.75651199e-04,
#        5.17429820e-04, 9.42583026e-04, 1.66634287e-03, 2.85881276e-03,
#        4.75974459e-03, 7.69056377e-03, 1.20589445e-02, 1.83500398e-02,
#        2.70982544e-02, 3.88349018e-02, 5.40106868e-02, 7.28976923e-02,
#        9.54826475e-02, 1.21370102e-01, 1.49718536e-01, 1.79232194e-01,
#        2.08225092e-01, 2.34761402e-01, 2.56860260e-01, 2.72736796e-01,
#        2.81039356e-01, 2.81039356e-01, 2.72736796e-01, 2.56860260e-01,
#        2.34761402e-01, 2.08225092e-01, 1.79232194e-01, 1.49718536e-01,
#        1.21370102e-01, 9.54826475e-02, 7.28976923e-02, 5.40106868e-02,
#        3.88349018e-02, 2.70982544e-02, 1.83500398e-02, 1.20589445e-02,
#        7.69056377e-03, 4.75974459e-03, 2.85881276e-03, 1.66634287e-03,
#        9.42583026e-04, 5.17429820e-04, 2.75651199e-04, 1.42509858e-04,
#        7.15000793e-05, 3.48132630e-05])

# %%
plt.plot(x, Ho)

# %%
mu = 70 
sigma = 2

s = np.random.normal(mu, sigma, 1000)
count, bins, ignored = plt.hist(s, 30, density=True)

# %%
abs(mu - np.mean(s)) < 0.01
True

abs(sigma - np.std(s, ddof=1)) < 0.01
True
# Out:
# True

# %%
#count, bins, ignored = plt.hist(s, 30, density=True)

# %%
 plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ), linewidth=2, color='r')

# %%
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
y = y.cumsum()
y /= y[-1]

plt.plot(bins, y, 'k--', linewidth=1.5, label='acumulativa')
#plt.plot(bins,  1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ))

# %%
from scipy.stats import norm
import seaborn as sns
# generate random numbers from N(0,1)
data_normal = norm.rvs(size=10000,loc=70,scale=2)
ax = sns.distplot(data_normal,
                  bins=100,
                  kde=True,
                  color='skyblue')
ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %% [markdown]
# ## Gamma distribution

# %% [markdown]
# You can generate a gamma distributed random variable using scipy.stats module's gamma.rvs() method which takes shape parameter a as its argument. When a is an integer, gamma reduces to the Erlang distribution, and when a=1 to the exponential distribution. To shift distribution use the loc argument, to scale use scale argument, size decides the number of random variates in the distribution. If you want to maintain reproducibility, include a random_state argument assigned to a number.

# %%
from scipy.stats import gamma
data_gamma = gamma.rvs(a=5, size=10000)

# %%
ax1 = sns.distplot(data_gamma,
                  kde=True,
                  bins=100,
                  color='skyblue')
ax1.set(xlabel='Gamma Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Gamma Distribution')]

# %%
data_gamma2 = gamma.rvs(a=1, size=10000)
ax2 = sns.distplot(data_gamma2,
                  kde=True,
                  bins=100,
                  color='skyblue')
ax2.set(xlabel='Gamma Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Gamma Distribution')]

# %% [markdown]
# ## Poisson disribution

# %%
from scipy.stats import poisson
data_poisson = poisson.rvs(mu=3, size=10000)

# %%
ax3 = sns.distplot(data_poisson,
                  bins=30,
                  kde=True,
                  color='skyblue')
ax3.set(xlabel='Poisson Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Poisson Distribution')]

# %% [markdown]
# ## Binomial distribution

# %%
from scipy.stats import binom
data_binom = binom.rvs(n=10,p=0.8,size=10000)

# %%
ax = sns.distplot(data_binom,
                  kde=True,
                  color='skyblue')
ax.set(xlabel='Binomial Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Binomial Distribution')]

# %% [markdown]
# ## Beta distribution

# %%
from scipy.stats import beta

# %%
a1, b1 =0.5,0.5
mean, var, skew, kurt = beta.stats(a, b, moments='mvsk')  #moments : str, optional composed of letters [‘mvsk’] specifying which moments to compute where ‘m’ = mean, ‘v’ = variance, ‘s’ = (Fisher’s) skew and ‘k’ = (Fisher’s) kurtosis. (default=’mv’)

# %%
fig, ax4 = plt.subplots(1, 1)
x = np.linspace(beta.ppf(0.01, a, b), beta.ppf(0.99, a, b), 100)
ax4.plot(x, beta.pdf(x, a, b), 'r-', lw=5, alpha=0.6, label='beta pdf')

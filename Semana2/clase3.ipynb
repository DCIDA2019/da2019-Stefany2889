# %%
import pandas as pd
import requests
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
import requests
import os
import math as mt

# %%
tab=pd.read_excel('/Users/stefany/Desktop/analisis_datos/da2019-Stefany2889/datos/2010_AT02__d-1.xls')

# %%
tab
# Out:
#    AT02d-1 Tasa de deserción total por entidad federativa, nivel o tipo educativo y sexo (2008/2009)  \
# 0                                                 NaN
# 1                    Entidad               federativa
# 2                                                 NaN
# 3                                                 NaN
# 4                                      Aguascalientes
# 5                                     Baja California
# 6                                 Baja California Sur
# 7                                            Campeche
# 8                                            Coahuila
# 9                                              Colima
# 10                                            Chiapas
# 11                                          Chihuahua
# 12                                   Distrito Federal
# 13                                            Durango
# 14                                         Guanajuato
# ...

# %% [markdown]
# Salarios en gto

# %%
salario=pd.read_excel('/Users/stefany/Desktop/analisis_datos/da2019-Stefany2889/datos/tabulador_pe2019.xls')

# %%
salario
# Out:
#    Unnamed: 0 Unnamed: 1                     Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         NaN        NaN                            NaN        NaN        NaN
# 1         NaN        NaN                            NaN        NaN        NaN
# 2         NaN        NaN                            NaN        NaN        NaN
# 3         NaN        NaN                            NaN        NaN        NaN
# 4         NaN        NaN                            NaN        NaN        NaN
# ..        ...        ...                            ...        ...        ...
# 83          1        NaN  OPERADOR/A ADMINISTRATIVO/A C    3374.28    657.984
# 84          1          A  OPERADOR/A ADMINISTRATIVO/A D     3080.4    600.678
# 85          1          A      OPERADOR/A DE SERVICIOS D     3080.4    600.678
# 86          1          A         OPERADOR/A COMERCIAL D     3080.4    600.678
# 87          1          A         OPERADOR/A TECNICO/A D     3080.4    600.678
#
# ...

# %% [markdown]
# Ya que se tiene categorías de sueldo por
#
# ¿Que porcentaje de su sueldo se pierde por las cuotas al issste, impuestos y inseg, respectivamente, para cada puesto?
# ¿Porcentaje se da de apoyo en sus diferentes modalidades para cada uno?
# Es equitativo o que definiria si hay un aumento o disminución de estos valores

# %%
url1 = "https://www.ncbi.nlm.nih.gov/books/NBK532684/table/ch4.tab1/?report=objectonly"
file1 = 'Population.csv'
if not os.path.isfile(file1):
    html1 = requests.get(url1).content
    df_list1 = pd.read_html(html1, header = 1)
    df1 = df_list1[-1]
    df1.to_csv('Population.csv')
else:
    df1 = pd.read_csv(file1)
df1


#url='https://smn.cna.gob.mx/tools/RESOURCES/com_archivo_datos_resumenes/201801010000Lluv.csv'
#html_tem= requests.get(url).content
#Birth_rate = pd.read_csv(html)[5]
# Out:
#     Sex, race, Hispanic origin, and year Total resident population  \
# 0                            All persons       Number in thousands
# 1                                   1950                    150697
# 2                                   1960                    179323
# 3                                   1970                    203212
# 4                                   1980                    226546
# ..                                   ...                       ...
# 136                                 2000                    100774
# 137                                 2010                    101741
# 138                                 2014                    102007
# 139                                 2015                    102060
# 140                                 2016                    102081
#
#             Under 1 year            1–4 years           5–14 years  \
# 0    Number in thousands  Number in thousands  Number in thousands
# ...

# %%
arch1='/Users/stefany/Desktop/analisis_datos/da2019-Stefany2889/datos/201901010000Lluv.csv'
arch1
# Out:
# '/Users/stefany/Desktop/analisis_datos/da2019-Stefany2889/datos/201901010000Lluv.csv'

# %% [markdown]
# Para la tabla de las temperaturas y presipitaciones por estado
#
# ¿Cómo varia la temperarura dependiendo de la cantidad de presipitaciones que hubo en el estado?
# ¿Se puede encontrar alguna relación entre estas temperaturas y la zona geografica?
# ¿

# %%
lluvias_2018 = pd.read_csv(arch1,encoding='latin-1')

# %% [markdown]
# print(lluvias_2018.values)
# print('--------------------------')
# print(lluvias_2018.values[1,4])

# %%
print(lluvias_2018.values)
print('--------------------------')
print(lluvias_2018.values[1,4])
# Out:
# [[-102.309722 21.895 'AGS' 'AGSAG' 'Aguascalientes, Ags.' 6.61]
#  [-102.466944 22.188610999999998 'AGS' 'ANVAG'
#   'Cincuenta Aniversario, Ags.' 10.6]
#  [-102.184167 21.738611 'AGS' 'BRTAG' 'San Bartolo, Ags.' 10.5]
#  ...
#  [-101.71583299999999 22.3475 'ZAC' 'VHGZC' 'Villa Hidalgo, Zac.' 9.7]
#  [-103.3375 21.588889 'ZAC' 'VILZC' 'José María Morelos, Zac.' 15.2]
#  [-102.576667 22.761389 'ZAC' 'ZACZC' 'Zacatecas, Zac.' 12.02]]
# --------------------------
# Cincuenta Aniversario, Ags.

# %%
lluvias_2018[4:20:2]
# Out:
#            LON        LAT  EDO CLAVE_SIH  \
# 4  -102.676944  21.997500  AGS     CDRAG
# 6  -102.189167  21.826667  AGS     CLVAG
# 8  -102.296667  22.362778  AGS     CSOAG
# 10 -102.788333  21.807500  AGS     MNLAG
# 12 -102.001944  22.020556  AGS     NVLAG
# 14 -102.465000  22.189167  AGS   P50ANIV
# 16 -102.291944  22.162500  AGS     PBLAG
# 18 -102.133333  22.202778  AGS     PTOAG
#
#                                     NOMBRE    ENE
# 4                        La Codorniz, Ags.  16.70
# 6                           Calvillo, Ags.   9.20
# 8                              Cosío, Ags.   7.20
# 10                        Media Luna, Ags.  24.30
# 12                        El Novillo, Ags.  15.50
# 14  Presa Cincuenta Aniversario, Ags. SMN*  10.40
# 16                          Pabellón, Ags.   6.80
# 18           Puerto de la Concepción, Ags.  11.53

# %%
url2 = 'https://www.indexmundi.com/map/?v=35&l=es'
html2 = requests.get(url2).content
VIH = pd.read_html(html2)[2]

# %%
VIH
# Out:
#                   País  VIH/SIDA - habitantes infectados con VIH/SIDA   Año
# 0            Sudáfrica                                        7100000  2018
# 1              Nigeria                                        3200000  2018
# 2                India                                        2100000  2018
# 3           Mozambique                                        1800000  2018
# 4                Kenia                                        1600000  2018
# ..                 ...                                            ...   ...
# 190           Singapur                                              0  2018
# 191     Estados Unidos                                              0  2018
# 192  Sáhara Occidental                                              0  2018
# 193              Samoa                                              0  2018
# 194        El Vaticano                                              0  2018
#
# [195 rows x 3 columns]
